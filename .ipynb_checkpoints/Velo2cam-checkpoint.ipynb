# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
from kitti_foundation import Kitti, Kitti_util
import cv2
import scipy as sp
import math
from math import cos, sin, radians, pi
from src import settings as st
from src import grids as gr
from src import history as hist
from src import foreground as frg
from src import association as asn
from src.tools import utils as util
import seaborn as sns
import pysort
# %matplotlib inline

# %%
settings = st.Settings()
data_path = './dataset/2011_09_30/'
velo_path = data_path + '/sequences/velodyne'
fr = 1060
image_path = data_path + '/color/image_02'
poses_path = data_path + '/poses/data'

# print frame 89 camera image
camera = Kitti(frame=fr,camera_path=image_path)
image = camera.camera_file

plt.imshow(image)
print(image.shape)
# Out:
# (370, 1226, 3)

# %%
def print_projection_cv2(points, color, image):
    """ project converted velodyne points into camera image """
    
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    for i in range(points.shape[1]):
        cv2.circle(hsv_image, (np.int32(points[0][i]),np.int32(points[1][i])),2, (int(color[i]),255,255),-1)

    return cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)

def print_projection_plt(points, color, image):
    """ project converted velodyne points into camera image """
    
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    for i in range(points.shape[1]):
        cv2.circle(hsv_image, (np.int32(points[0][i]),np.int32(points[1][i])),2, (int(color[i]),255,255),-1)

    return cv2.cvtColor(hsv_image, cv2.COLOR_HSV2RGB)

# %%
""" save one frame about projecting velodyne points into camera image """
v_fov, h_fov = (-24.9, 20.0), (-90, 90)

v2c_filepath = data_path + '/calibration/calib_velo_to_cam.txt'
c2c_filepath = data_path + '/calibration/calib_cam_to_cam.txt'

res = Kitti_util(frame=fr, camera_path=image_path, velo_path=velo_path, poses_path=poses_path, \
                v2c_path=v2c_filepath, c2c_path=c2c_filepath)

img, pnt, c_  = res.velo_projection_frame(v_fov=v_fov, h_fov=h_fov)

result = print_projection_plt(pnt, c_, img)

# display result image
plt.subplots(1,1, figsize = (13,3) )
plt.title("Velodyne points to camera image Result")
plt.imshow(result)

# %%
poses_path = data_path + '/poses/poses.txt'
poses = np.loadtxt(poses_path)
c2v = np.asarray([[0, 0, 1],[-1, 0, 0],[0, -1, 0]])
# c2v = np.asarray([[0, 0, 1],[-1, 0, 0],[0, -1, 0]])
# print(c2v)
T = poses[0].reshape(3,4)
R = c2v.dot(T[0:3,0:3].dot(c2v.T))
t = c2v.dot(T[0:3,3])
print(R)
print(t)
stack = []
a = np.asarray([1,2])
for i in range(5):
    stack.append(a+i)
print(stack[:])
print(stack[:][1][0])
# np.sum(stack[0:3][0])
point = np.zeros(3)
print(point[0], point[1], point[2])
# Out:
# [[ 1.000000e+00 -1.704638e-10 -3.562503e-10]
#  [-1.704638e-10  1.000000e+00  1.197625e-11]
#  [-3.562503e-10  1.197625e-11  1.000000e+00]]
# [2.220446e-16 0.000000e+00 1.110223e-16]
# [array([1, 2]), array([2, 3]), array([3, 4]), array([4, 5]), array([5, 6])]
# 2
# 0.0 0.0 0.0

# %%
cluster_distance_threshold = 1
min_cluster_size = 3

history = hist.History(settings)
foreground = frg.Foreground(settings)
association = asn.Association(settings)

tracker_type = pysort.TRACKER_TYPES
iou_threshold = 0.3
max_age = 5
min_hit_streak = 3
tracker = pysort.Sort(int(tracker_type.TRACK_BBOX), iou_threshold, max_age, min_hit_streak)
counter = 0
for f in range(5):
    res = Kitti_util(frame=fr+f, camera_path=image_path, velo_path=velo_path, poses_path=poses_path,  \
                    v2c_path=v2c_filepath, c2c_path=c2c_filepath)
    T = poses[fr+f].reshape(3,4)
    
    R = c2v.dot(T[0:3,0:3].dot(c2v.T))
    t = c2v.dot(T[0:3,3])
    print(R,t)
    
    x_range, y_range, z_range, scale = (-12, 40), (-12, 12), (-2, 1), 10
    pnt_velo, c = res.velo_points(x_range=x_range, y_range=y_range, z_range=z_range)
    
    pnt_velo[2,:] = pnt_velo[2,:] + 1.73 # Add floor bias
    

#     for i in range(100):
#         print( pnt_velo[:,i])
    # Get rotation and translation from GPS/IMU for the current frame
#     R, t = util.pose_from_oxts_packet(res.poses_file)

    grid = gr.Grid(settings, R, t)
    
    # create 2.5D grid from velodine points
    print('creating 2.5D grid')
    grid.build_height_grid(pnt_velo)
    
    # model background 
    print('Modeling history')
    history.model_history(grid, R, t)
    
    if len(history.stack) > 1:
        # model foreground
        print('Extract foreground')
        foreground.create_motion_grid(history.bgr_grid, grid, R, t)
        frg_grid = foreground.frg_grid
        frg_grid = np.multiply(frg_grid >= 0, frg_grid)
        frg_img = (255*(frg_grid )/np.ptp(frg_grid)).astype(np.uint8)  

        # Get clusters
        print("Clustering")
        box_indexes = []
#         for i in range(foreground.frg_points.shape[1]):
#             print(foreground.frg_points_transformed[:,i])
        association.cluster_points(foreground.frg_points, cluster_distance_threshold, min_cluster_size)
        association.get_cluster_centroids(association.clusters)
        box_indexes = association.get_box_as_index(association.boxes)
        
        
        detections = []
        print("box_indexes", len(box_indexes))
        for box in box_indexes:
            box = util.increase_bbox(box, 5, 5)
            bbox = util.convert_detection_to_bbox(box)
            print(bbox)
#             conf = 1.
#             classId = 1
#             det = pysort.detections(bbox, conf, classId, 0., 0., 0.)
# #             print(det)
#             detections.append(det)
        
#         tracked_detections = tracker.Update(detections)
        
        print("Draw rectangles")
#         print("Tracked detections",len(tracked_detections))
#         for trkID in tracked_detections:
#             det = tracked_detections[trkID]
#             (x1, y1) = (det.box[0], det.box[1])
#             (x2, y2) = (x1 + det.box[2], y1 + det.box[3])
#             print("ID",trkID, x1,y1,x2,y2)
#             cv2.rectangle(frg_img, (y1, x1), (y2, x2), (255, 255, 255), 1)
        
        for b in box_indexes:
            x1 = int(b[0])
            y1 = int(b[2])
            x2 = int(b[1])
            y2 = int(b[3])
    #         print(x1,y1,x2,y2)
            cv2.rectangle(frg_img, (y1, x1), (y2, x2), (255, 255, 255), 1)
        
        counter+= 1
        stillProcess=True
        while stillProcess is True:
            cv2.imshow('img', frg_img)
            #wait a little to let the time for figures to be drawn
            key = cv2.waitKey(1)
            if key == 32: # Space
                stillProcess = False
                cv2.imwrite('img/frg_img_' + str(fr+f) + '.png', frg_img)
            elif key == 27: # ESC
                stillProcess = False
        if key == 27:
            break

cv2.destroyAllWindows()
# Out:
# [[ 0.9993144   0.03601971 -0.00856474]
#  [-0.03592686  0.9992965   0.0107583 ]
#  [ 0.00894623 -0.01044322  0.9999054 ]] [265.167     2.24888   5.58502]
# creating 2.5D grid
# Modeling history
# [[ 0.9992926   0.03650683 -0.00902633]
#  [-0.03640937  0.9992793   0.01073554]
#  [ 0.00941175 -0.01039931  0.9999016 ]] [266.0593     2.217026   5.60834 ]
# creating 2.5D grid
# Modeling history
# Extract foreground
# Clustering
# box_indexes 10
# [12, 20, 9, 18]
# [58, 1, 2, 2]
# [72, 35, 0, 3]
# [90, 42, 2, 1]
# [111, 104, 5, 1]
# [125, 38, 5, 5]
# [134, 105, 4, 1]
# [197, 43, 4, 4]
# [205, 53, 2, 3]
# [237, 49, 2, 1]
# Draw rectangles
# [[ 0.9992875   0.03658545 -0.00927618]
#  [-0.03650557  0.9992961   0.00863937]
#  [ 0.00958573 -0.00829458  0.9999196 ]] [266.9604     2.181048   5.632766]
# creating 2.5D grid
# Modeling history
# Extract foreground
# Clustering
# box_indexes 11
# [18, 25, 9, 13]
# [62, 1, 2, 2]
# [75, 35, 3, 3]
# [95, 42, 2, 1]
# [102, 110, 1, 1]
# [129, 39, 5, 4]
# ...

# %%
sns.color_palette("flare", as_cmap=True)
fig, ax2 = plt.subplots(1,1,figsize= (5,10))
sns.heatmap(ax=ax2, data=history.bgr_grid)
# Out:
# <AxesSubplot:>

# %%
sns.color_palette("flare", as_cmap=True)
fig, ax2 = plt.subplots(1,1,figsize= (5,10))
# ax2.imshow(grid.grid, cmap='hot', interpolation='nearest')
# plt.show()
sns.heatmap(ax=ax2, data=grid.grid)
# Out:
# <AxesSubplot:>

# %%
sns.color_palette("flare", as_cmap=True)
fig, ax2 = plt.subplots(1,1,figsize= (5,10))
sns.heatmap(ax=ax2, data=foreground.frg_grid)
frg_grid = foreground.frg_grid
frg_grid = np.multiply(frg_grid >= 0, frg_grid)
img = (255*(frg_grid )/np.ptp(frg_grid)).astype(np.uint8)  
# print(img)
# ax2.imshow(img)

# %%
# association.cluster_points(history.stack[2].grid_points, cluster_distance_threshold, min_cluster_size)
association.cluster_points(foreground.frg_points, cluster_distance_threshold, min_cluster_size)
print("cluster 0: ", association.clusters[0])

association.get_cluster_centroids(association.clusters)
print("centroid 0 : ", association.centroids[0])
print("centroid len : ", len(association.centroids))
print("box 0: ", association.boxes[0])

centerasindex = association.get_point_as_index(association.centroids)
print("center: ",centerasindex[0])

box = association.get_box_as_index(association.boxes)
print("box: ", box[0])

print("Draw rectangles")
print("Num rectangles", len(box_indexes))
frg_img
for b in box_indexes:
    x1 = int(b[0])
    y1 = int(b[2])
    x2 = int(b[1])
    y2 = int(b[3])
    print(y1,x1,y2,x2)
    cv2.rectangle(frg_img, (y1, x1), (y2, x2), (255, 255, 255), 1)
fig, ax2 = plt.subplots(1,1,figsize= (5,10))
ax2.imshow(frg_img, cmap='hot', interpolation='nearest')
plt.show()
# Out:
# cluster 0:  [array([-14.4,  -5. ,   1. ]), array([-14.2,  -4.2,   1. ]), array([-14. ,  -5.8,   1. ]), array([-14.,  -5.,   1.]), array([-14. ,  -4.2,   1. ]), array([-13.8,  -5.6,   1. ]), array([-13.6,  -5.2,   1. ]), array([-14.2,  -3.8,   1. ]), array([-14. ,  -4.2,   1. ]), array([-13.8,  -5.6,   1. ]), array([-13.6,  -6.6,   1. ]), array([-13.6,  -5.2,   1. ]), array([-13.4,  -6.4,   1. ]), array([-13.4,  -5.8,   1. ]), array([-13.2,  -5.8,   1. ]), array([-13.2,  -5.4,   1. ]), array([-14. ,  -4.2,   1. ]), array([-13.4,  -4.8,   1. ]), array([-13.2,  -5.4,   1. ]), array([-13.2,  -5. ,   1. ]), array([-13.2,  -4.6,   1. ]), array([-13.4,  -4.8,   1. ]), array([-13.2,  -4.6,   1. ]), array([-13.2,  -4. ,   1. ]), array([-13.6,  -6.4,   1. ]), array([-13.4,  -6.4,   1. ]), array([-13.2,  -5.2,   1. ]), array([-13.2,  -5.2,   1. ]), array([-13.2,  -4.4,   1. ]), array([-13.,  -5.,   1.]), array([-13. ,  -4.6,   1. ]), array([-13.2,  -4.4,   1. ]), array([-13.4,  -6.4,   1. ]), a
# ...

# %%
centroid_indexes = []
for c in centroids:
#     print(c)
    idx = np.divide(c[0:2], np.asarray([settings.cell_size_x, settings.cell_size_y]))
    idx = np.floor(np.add(idx, np.asarray([-settings.grid_xb/settings.cell_size_x, 
                                           -settings.grid_yr/settings.cell_size_y])))
#     print(idx)
    centroid_indexes.append(idx)
    
box_indexes = []
for b in boxes:
    idx = np.divide(b[0:4], np.asarray([settings.cell_size_x, settings.cell_size_x, 
                                        settings.cell_size_y, settings.cell_size_y]))
    idx = np.floor(np.add(idx, np.asarray([-settings.grid_xb/settings.cell_size_x, 
                                           -settings.grid_xb/settings.cell_size_x, 
                                           -settings.grid_yr/settings.cell_size_y, 
                                           -settings.grid_yr/settings.cell_size_y])))
    box_indexes.append(idx)
print("centroids",centroid_indexes[0])
print("boxes",box_indexes[0])

for b in box_indexes:
    x1 = int(b[0])
    y1 = int(b[2])
    x2 = int(b[1])
    y2 = int(b[3])
    print(x1,y1,x2,y2)
    cv2.rectangle(img, (y1, x1), (y2, x2), (255, 255, 255), 1)

stillProcess=True
while stillProcess is True:
    
    cv2.imshow('img', img)
    #wait a little to let the time for figures to be drawn
    key = cv2.waitKey(1)
    if key == 27:
        stillProcess = False
    
cv2.destroyAllWindows()
