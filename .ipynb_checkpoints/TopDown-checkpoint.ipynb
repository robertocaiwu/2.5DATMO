# %%
import numpy as np
import matplotlib.pyplot as plt
from kitti_foundation import Kitti, Kitti_util
import cv2
import math
from math import cos, sin, radians, pi
from src import settings as st
import seaborn as sns
# %matplotlib inline

# %%
settings = st.Settings()
data_path = './dataset/2011_09_30/'
velo_path = data_path + '/sequences/velodyne'

velo = Kitti(frame=0, velo_path=velo_path)
frame = velo.velo_file

print(frame.shape)
# Out:
# (123020, 3)

# %%
image_path = data_path + '/color/image_02'
fr = 189
# print frame 89 camera image
camera = Kitti(frame=fr,camera_path=image_path)
image = camera.camera_file

plt.imshow(image)
print(image.shape)
# Out:
# (370, 1226, 3)

# %%
x_range, y_range, z_range, scale = (-20, 20), (-20, 20), (-2, 2), 10
topview_img = velo.velo_2_topview_frame(x_range=x_range, y_range=y_range, z_range=z_range)

# Plot result
plt.subplots(1,1, figsize = (5,5))
plt.imshow(topview_img)
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-84dab86867da> in <module>
#       1 x_range, y_range, z_range, scale = (-20, 20), (-20, 20), (-2, 2), 10
# ----> 2 topview_img = velo.velo_2_topview_frame(x_range=x_range, y_range=y_range, z_range=z_range)
#       3
#       4 # Plot result
#       5 plt.subplots(1,1, figsize = (5,5))
#
# AttributeError: 'Kitti' object has no attribute 'velo_2_topview_frame'
